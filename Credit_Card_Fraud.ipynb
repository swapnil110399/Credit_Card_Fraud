# %% [markdown]
# # CREDIT CARD FRUD DETECTION

# %% [markdown]
# In this project the challenge is to recognize fraudulent credit card transactions so that the customers of credit card companies are not charged for items that they did not purchase.

# %% [markdown]
# The dataset for this project is downloaded from https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# While going through the data we will find that the data is extremely unbalanced and we will use machine laerning algorithms and deal with the unbalanced

# %% [markdown]
# ## IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## LOAD THE DATA INTO GOOGLE DRIVE

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-291d6164-ceb5-4ed4-b1db-a4305be48668" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-291d6164-ceb5-4ed4-b1db-a4305be48668">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ## LOADING THE DATA

# %%
import io
data=pd.read_csv("/content/creditcard.csv")

# %% [markdown]
# ## EDA

# %% [markdown]
# View the data set given

# %%
data
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# Shape of the data set

# %%
data.shape
# Out:
# (284807, 31)

# %% [markdown]
# View the columns of the dataset

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# View the top 6 rows

# %%
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# View the last 6 rows

# %%
data.tail()
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [5 rows x 31 columns]

# %% [markdown]
# calculating some statistical data like percentile, mean and std of the numerical values

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# Getting  information about the data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# Checking for null values

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# no missing data

# %% [markdown]
# Checking the number of fraud and non fraud cases

# %%
count_classes=data['Class'].value_counts()
count_classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
not_fraud=data[data['Class']==0]
fraud=data[data['Class']==1]

# %%
not_fraud.shape,fraud.shape
# Out:
# ((284315, 31), (492, 31))

# %%
percentage_fraud=fraud.shape[0]/(not_fraud.shape[0]+fraud.shape[0])

# %%
percentage_fraud
# Out:
# 0.001727485630620034

# %% [markdown]
# We find that the number of frauds is very less when comapred to the non fraud cases so this data set is extermly unbalanced

# %% [markdown]
# ## PLOTTING FEW GRAPHS

# %%
data.hist(bins=50,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5658cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab560fdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab55cc080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab556edd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab55a9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab555b2e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5504fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab54be358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab54be3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab549ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab544be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab54091d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab53bb550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab53ed8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab539ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5352fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5310390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab52c1710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5273a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab52a7e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab52671d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5216550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab51ca8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab517bc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5131fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab50ef390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab511f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab50d1a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab5082e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab50421d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab4ff2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab50258d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab4fd6c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab4f8cfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab4f4b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5ab4efb710>]],
#       dtype=object)

# %% [markdown]
# ### PLOTTING THE FRAUD AND NON FRAUD

# %%
sns.barplot(count_classes.index,count_classes.values)

# %% [markdown]
# ### PLOTTING THE CORRELATION MATRIX

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col2 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col5 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col7 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col8 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col10 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col12 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col14 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col16 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col17 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col18 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col19 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col21 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col22 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col23 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col29 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row0_col30 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col2 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col5 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col8 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col9 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col10 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col11 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col13 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col14 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col15 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col16 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col17 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col18 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col19 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col20 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col22 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col23 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col24 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col25 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col26 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col27 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_8ad9d002_e858_11ea_b8f9_0242ac1c0002row1_col28 {
#             background-color:  #

# %% [markdown]
# The percentage of the fraud and non farud values in the dataset

# %%
print('NO Frauds',percentage_fraud,'% of the dataset')
print('Frauds',1-percentage_fraud,'% of the dataset')
# Out:
# NO Frauds 0.001727485630620034 % of the dataset
# Frauds 0.9982725143693799 % of the dataset

# %% [markdown]
# ## SPLITTING THE DATASET INTO TRAINING AND TESTING DATASET

# %% [markdown]
# We will split the dataset into training and testing datasets and using stratified k flod

# %% [markdown]
# #### IMPORTING THE LIBRARIES

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# We split the dataset into features and labels

# %%
X=data.drop('Class',axis=1)
y=data['Class']

# %% [markdown]
# Using the startified k flod we split the dataset into traning and testing data

# %%
sk=StratifiedKFold(n_splits=5,random_state=None,shuffle=False)
for train,test in sk.split(X,y):
  print("Train:",train,"Test:",test)
  X_train,X_test=X.iloc[train],X.iloc[test]
  y_train,y_test=y.iloc[train],y.iloc[test]
# Out:
# Train: [ 30473  30496  31002 ... 284804 284805 284806] Test: [    0     1     2 ... 57017 57018 57019]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [ 30473  30496  31002 ... 113964 113965 113966]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [ 81609  82400  83053 ... 170946 170947 170948]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [150654 150660 150661 ... 227866 227867 227868]
# Train: [     0      1      2 ... 227866 227867 227868] Test: [212516 212644 213092 ... 284804 284805 284806]

# %%
X_train = X_train.values
X_test = X_test.values
y_train =y_train.values
y_test = y_test.values

# %% [markdown]
# The shape of the training and testing data

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((227846, 30), (56961, 30), (227846,), (56961,))

# %% [markdown]
# ## MODEL

# %% [markdown]
# As the dataset is very unbalanced we would be using IsolationForest and LocalOutlierFactor machine learning algorithms

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from pylab import rcParams

# %%
import scipy
state = np.random.RandomState(42)

# %% [markdown]
# ## Isolation Forest

# %%
IF=IsolationForest(n_estimators=100, max_samples=len(X_train), 
                                       contamination=percentage_fraud,random_state=state, verbose=0)

# %%
IF.fit(X_train,y_train)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False,
#                 contamination=0.001727485630620034, max_features=1.0,
#                 max_samples=227846, n_estimators=100, n_jobs=None,
#                 random_state=RandomState(MT19937) at 0x7F5AB99C7DB0, verbose=0,
#                 warm_start=False)

# %% [markdown]
# Predicting the values for testing data

# %%
y_if_pred=IF.predict(X_test)

# %%
y_if_pred[y_if_pred==1]=0
y_if_pred[y_if_pred==-1]=1

# %% [markdown]
# Counting the values of values which were predicted wrongly

# %%
n_if_errors = (y_if_pred != y_test).sum()

# %% [markdown]
# ### SUMMARY OF THE MODEL

# %%
print("The IsolationForest has {} errors".format(n_errors))
print("Accuracy Score :")
print(accuracy_score(y_test,ys_pred))
print("Classification Report :")
print(classification_report(y_test,y_if_pred))
# Out:
# The IsolationForest has 152 errors
# Accuracy Score :
# 0.997331507522691
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       0.14      0.11      0.13        98
#
#     accuracy                           1.00     56961
#    macro avg       0.57      0.56      0.56     56961
# weighted avg       1.00      1.00      1.00     56961

# %% [markdown]
# ## CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ys_pred) 
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# %% [markdown]
# ## Local Outlier Factor

# %%
LOF=LocalOutlierFactor(n_neighbors=20, algorithm='auto', 
                                              leaf_size=30, metric='minkowski',
                                              p=2, metric_params=None, contamination=percentage_fraud)

# %%
LOF.fit(X_train,y_train)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.001727485630620034,
#                    leaf_size=30, metric='minkowski', metric_params=None,
#                    n_jobs=None, n_neighbors=20, novelty=False, p=2)

# %% [markdown]
# Predicting the values for testing data

# %%
y_lof_pred=LOF.fit_predict(X_test)

# %%
y_lof_pred[y_lof_pred==1]=0
y_lof_pred[y_lof_pred==-1]=1

# %% [markdown]
# Counting the values of values which were predicted wrongly

# %%
na_errors = (y_lof_pred != y_test).sum()

# %% [markdown]
# ### SUMMARY OF THE MODEL

# %%
print("The LocalOutlierFactor has {} errors".format(na_errors))
print("Accuracy Score :")
print(accuracy_score(y_test,ya_pred))
print("Classification Report :")
print(classification_report(y_test,y_lof_pred))
# Out:
# The LocalOutlierFactor has 163 errors
# Accuracy Score :
# 0.9971383929355173
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       0.17      0.17      0.17        98
#
#     accuracy                           1.00     56961
#    macro avg       0.59      0.59      0.59     56961
# weighted avg       1.00      1.00      1.00     56961

# %% [markdown]
# ### CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ya_pred) 
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# %% [markdown]
# Isolation forest detected 152 errors versus Lcal outlier Factor 163 errors

# %% [markdown]
# Isolation forest has a accuracy of 0.997331507522691  and Lcal outlier Factor has 0.9971383929355173
